# %%
install.packages("igraph")
library('igraph')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Attaching package: ‘igraph’
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union

# %%
g_3 = sample_pa_age(n=1000, m=1, pa.exp=1, aging.exp=-1, directed=FALSE)
plot(degree.distribution(g_3), log="xy", main="Network with node age panelization", xlab="log Degree", ylab="Distribution")

#power law exponent gamma
deg_distribution1 = degree.distribution(g_3)
log_deg1 = log(seq(1,length(deg_distribution1[-1]))) 
#log_deg1 = log(seq(1,max(degree(g1)))) #same
log_distribution1 = log(deg_distribution1[-1])

idx1 = which(log_distribution1 != -Inf, arr.ind=TRUE)
log_distribution1= log_distribution1[c(idx1)]
log_deg1 = log_deg1[c(idx1)]


lm(log_distribution1~log_deg1)
abline(lm(log_distribution1~log_deg1))
# Out:
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “4 y values <= 0 omitted from logarithmic plot”
# Call:
# lm(formula = log_distribution1 ~ log_deg1)
#
# Coefficients:
# (Intercept)     log_deg1
#      0.2044      -2.6561
# Plot with title “Network with node age panelization”

# %% [markdown]
# gamma = - slope = 2.6561

# %%
setEPS()
postscript("1_3_a.eps")
plot(degree.distribution(g_3), log="xy", main="Network with node age panelization", xlab="log Degree", ylab="Distribution")
lm(log_distribution1~log_deg1)
abline(lm(log_distribution1~log_deg1))
dev.off()
# Out:
# Warning message in xy.coords(x, y, xlabel, ylabel, log):
# “4 y values <= 0 omitted from logarithmic plot”
# Call:
# lm(formula = log_distribution1 ~ log_deg1)
#
# Coefficients:
# (Intercept)     log_deg1
#      0.2044      -2.6561
# png
#   2

# %%
pa_com = cluster_fast_greedy(g_3)
pa_mod = modularity(pa_com)
cat("Modularity =  ", pa_mod)
plot(pa_com, g_3, vertex.size=5, vertex.label=NA, main="Network with Communities, n = 1000")
# Out:
# Modularity =   0.9351393
# Plot with title “Network with Communities, n = 1000”

# %%
setEPS()
postscript("1_3_b.eps")
plot(pa_com, g_3, vertex.size=5, vertex.label=NA, main="Network with Communities, n = 1000")
dev.off()
# Out:
# Warning message in xspline(cl$rescoords, shape = shape, open = FALSE, col = col, :
# “semi-transparency is not supported on this device: reported only once per page”
# png
#   2
